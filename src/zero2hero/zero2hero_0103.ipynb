# %% [markdown]
# # Zero to Hero

# %% [markdown]
# ## 1.03  Construyendo un arbol

# %% [markdown]
# Se construye un arbol de decisión, se ven distintas formas de pasar los parámetros y distintas formas de dibujarlo.
# <br>
# Se muestran funcionalidades básicas de0la libreria  *data.table*

# %%
library("data.table") # cargo la libreria  data.table
library("rpart") # cargo la libreria  rpart

# %%
options(repr.plot.width = 25, repr.plot.height = 25) # para que los gráficos me salgan legibles

# %%
setwd("~/buckets/b1/")

# %%
dataset <- fread("~/datasets/vivencial_dataset_pequeno.csv")

# %% [markdown]
# Ahora entreno un arbol de decision
# <br>
# "clase_ternaria ~ ."  significa predecir clase_ternaria utilizando *todo el resto* de las variables del dataset

# %%
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107]
)

# %% [markdown]
# Imprimo el modelo con la muy básica funcion print() de la libreria rpart

# %%
print(modelo)
# Out:
# n= 164596
#
# node), split, n, loss, yval, (yprob)
#       * denotes terminal node
#
# 1) root 164596 2385 CONTINUA (0.006907823 0.007582201 0.985509976) *

# %% [markdown]
# Esta impresión no es gráfica. No me sirve.
# <br>
# a pesar que no me sirve, he encontrado una piedra en el camino, me está generando un arbol con un solo nodo, con solo la raiz

# %% [markdown]
# Busco bibliografía y encuentro que existe la libreria  **rpart.plot** que grafica arboles generados con la libreria  *rpart*

# %%
library("rpart.plot")

# %%
rpart.plot::prp(modelo)
# Out:
# plot without title

# %% [markdown]
# Me ha salido una impresión del arbol, que es un solo nodo, pero solo dice continua.
# <br>
# leo la documentacion de la librería rpart.plot   https://cran.r-project.org/web/packages/rpart.plot/rpart.plot.pdf

# %%
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.3)
# Out:
# plot without title

# %% [markdown]
# Ha salido solo la raiz del arbol
# <br>
# Los tres numeros que muestra en el nodo con la cantidad de BAJA+1, BAJA+2 y CONTINUA, en ese orden, alfabetico.
# <br>
# la cantidad de CONTINUA   la está mostrando en notacion científica

# %% [markdown]
# ### cambio hiperparámetros del arbol para salga algo mas que un solo nodo

# %% [markdown]
# El hiperparámetro cp  *complexity*   limita el split de los nodos.
# <br>
# El default es  cp=0.05
# <br>
# Pruebo con cp=0.0  a ver si "se abre el arbol"

# %% [markdown]
# Leo la documentación de la libreria rpart  https://cran.r-project.org/web/packages/rpart/rpart.pdf   y veo que existe un hiperparámetro de la funcion rpart  llamado **xval** que es para hacer cross validation, que por default viene seteado en xval=10 .   No me interesa en este momento que haga cross validation, para evitarlo voy a poner  *xval=0*

# %%
# genero el modelo
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107],
    xval = 0,
    cp = 0.0
)

# imprimo el modelo graficamente
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.3)
# Out:
# Warning message:
# “labs do not fit even at cex 0.15, there may be some overplotting”
# plot without title

# %% [markdown]
# sale un arbol de gran profundidad  que ni se puede visualizar
# <br>
# el mensaje  ""labs do not fit even at cex 0.15, there may be some overplotting"" me dice que no pudo dibujarlo correctamente
# <br>
# lamentablemente me doy cuenta la libreria rpart.plot es mala
# <br>
# establezco  maxdepth=2 para poder apreciarlo

# %%
# genero el modelo
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107],
    xval = 0,
    cp = 0.0,
    maxdepth = 2
)

# imprimo el modelo graficamente
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.3, cex = 1.2)
# Out:
# Warning message:
# “cex and tweak both specified, applying both”
# plot without title

# %% [markdown]
# Esperaba ver un albol de profundidad 2 sin embargo, por alguna misteriosa razón, se ha generado un arbol con un solo nodo.
# <br>
# Corto por lo sano,  y establezco  cp=-1  para que siempre se abra el arbol

# %% [markdown]
# #genero el modelo
# modelo < -rpart(formula="clase_ternaria ~ .",
#     data=dataset1,
#     xval=0,
#     cp=-1,
#     maxdepth=3)
#
# #imprimo el modelo graficamentne
# prp(modelo, extra=101, digits=5, branch=1, type=4, varlen=0, faclen=0, tweak=1.3)

# %%
# genero el modelo
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107],
    xval = 0,
    cp = -1,
    maxdepth = 3
)

# imprimo el modelo graficamente
options(repr.plot.width = 40, repr.plot.height = 20)
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.1, cex = 1.2)
# Out:
# Warning message:
# “cex and tweak both specified, applying both”
# plot without title

# %%
# genero el modelo
dataset2 <- copy(dataset)
julio <- copy(dataset[foto_mes == 202107])
dataset2[foto_mes == 202109, clase_ternaria := "Z01"]
julio[, clase_ternaria := "Z01"]
dataset2 <- rbind(dataset2, julio)
dataset2[, foto_mes := NULL]
setorder(dataset2, clase_ternaria)

modelo <- rpart(
    formula = "clase_ternaria ~ . -Master_fultimo_cierre -Visa_fultimo_cierre -mcomisiones_mantenimiento",
    data = dataset2,
    xval = 0,
    cp = -1,
    maxdepth = 3
)

# imprimo el modelo graficamente
options(repr.plot.width = 40, repr.plot.height = 20)
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.1, cex = 1.2)
# Out:
# Warning message:
# “cex and tweak both specified, applying both”
# plot without title

# %%
modelo$splits
# Out:
#                                   count  ncat improve      index
# Visa_msaldodolares                471701 -1   1381.2029907      113.780
# mcomisiones                       494285  1   1146.5299598       -0.005
# mcomisiones_otras                 494285  1   1143.1262631       -0.005
# ctarjeta_visa_descuentos          494285  1    733.9164716        0.500
# cliente_antiguedad                494285 -1    694.0481639      326.500
# mtarjeta_visa_consumo              22584 -1      0.8512829   261531.065
# ctarjeta_visa_debitos_automaticos      0 -1      0.8507042       16.500
# ctarjeta_visa_transacciones            0 -1      0.8498010       79.500
# Visa_msaldototal                       0 -1      0.8496887   390289.605
# Visa_mpagado                           0 -1      0.8494131   253326.845
# mcomisiones                       423086  1   1138.4240303       -0.005
# mcomisiones_otras                 423086  1   1136.1459116       -0.005
# Visa_mconsumosdolares             361774  1    882.0931264        1.080
# cliente_antiguedad                423086 -1    557.3351226      326.500
# ctarjeta_visa_descuentos          423086  1    532.5826907        0.500
# mcomisiones_otras                      0  1      0.9999362       -0.005
# ccajas_depositos                       0 -1      0.9773119       11.500
# ccheques_emitidos                      0 -1      0.9772978       53.500
# mcheques_emitidos                      0 -1      0.9772859 23342339.080
# Visa_mconsumosdolares             354755  1    805.0012710        1.080
# cliente_antiguedad                413474 -1    578.2799655      326.500
# ctarjeta_visa_descuentos          413474  1    484.8283457        0.500
# ctarjeta_master_descuentos        413474  1    453.3186762        0.500
# Master_fechaalta                  370494 -1    416.3359318     7724.500
# Visa_msaldodolares                 37060  1      0.8623022      107.900
# Visa_mconsumospesos                    0 -1      0.8517428       -0.950
# Visa_mconsumototal                     0 -1      0.8517428       -0.950
# Visa_mpagosdolares                     0  1      0.8474158        0.585
# Visa_cconsumos                         0  1      0.8466632      100.500
# ccomisiones_mantenimiento           9612  1    253.9916813        0.500
# ⋮                                 ⋮      ⋮    ⋮            ⋮
# Visa_mpagosdolares                71199   1   811.8574978        1.295
# Visa_msaldodolares                71199   1   489.5823618      220.275
# ctarjeta_visa_descuentos          71199   1   277.3316626        0.500
# ctarjeta_master_descuentos        71199   1   259.7134422        0.500
# Visa_mconsumosdolares             71199   1   194.8766235        4.855
# mcaja_ahorro                          0   1     0.6096715    85595.370
# mpasivos_margen                       0   1     0.5987444     3847.035
# mcuentas_saldo                        0   1     0.5983230   281121.860
# Visa_mlimitecompra                    0   1     0.5867217  1149365.525
# mtransferencias_recibidas             0   1     0.5842357   346332.365
# Visa_msaldodolares                30357  -1    97.4388387      343.825
# ctarjeta_visa_descuentos          30357   1    78.5360008        0.500
# cliente_antiguedad                30357  -1    64.1449223      326.500
# ctarjeta_master_descuentos        30357   1    62.0090604        0.500
# Master_fechaalta                  29260  -1    61.9484486     7724.500
# Visa_mconsumosdolares                 0  -1     0.9136937        3.505
# Visa_mpagosdolares                    0  -1     0.8562111        3.555
# Visa_mconsumospesos                   0  -1     0.8010014      339.500
# Visa_mconsumototal                    0  -1     0.8010014      339.500
# mtarjeta_visa_consumo                 0  -1     0.7944132      342.695
# Visa_msaldodolares                40842   1   378.8141861      556.140
# Visa_mconsumosdolares             40842   1   300.8960750        5.565
# ctarjeta_master_descuentos        40842   1   195.5964686        0.500
# ctarjeta_visa_descuentos          40842   1   159.5786994        0.500
# mtarjeta_master_descuentos        39893   1   109.3209612       92.490
# Visa_mconsumosdolares                 0   1     0.9584986        5.635
# Visa_mpagominimo                      0   1     0.6387542     3513.135
# Visa_mpagosdolares                    0  -1     0.6106459        0.975
# Visa_mconsumospesos                   0   1     0.6104500     4352.030
# Visa_mconsumototal                    0   1     0.6104500     4352.030
#                                   adj
# Visa_msaldodolares                0.0000000000
# mcomisiones                       0.0000000000
# mcomisiones_otras                 0.0000000000
# ctarjeta_visa_descuentos          0.0000000000
# cliente_antiguedad                0.0000000000
# mtarjeta_visa_consumo             0.0147333530
# ctarjeta_visa_debitos_automaticos 0.0108990295
# ctarjeta_visa_transacciones       0.0049157994
# Visa_msaldototal                  0.0041714069
# Visa_mpagado                      0.0023455386
# mcomisiones                       0.0000000000
# mcomisiones_otras                 0.0000000000
# Visa_mconsumosdolares             0.0000000000
# cliente_antiguedad                0.0000000000
# ctarjeta_visa_descuentos          0.0000000000
# mcomisiones_otras                 0.9971910112
# ccajas_depositos                  0.0013524761
# ccheques_emitidos                 0.0007282563
# mcheques_emitidos                 0.0002080732
# Visa_mconsumosdolares             0.0000000000
# cliente_antiguedad                0.0000000000
# ctarjeta_visa_descuentos          0.0000000000
# ctarjeta_master_descuentos        0.0000000000
# Master_fechaalta                  0.0000000000
# Visa_msaldodolares                0.1022549758
# Visa_mconsumospesos               0.0334111334
# Visa_mconsumototal                0.0334111334
# Visa_mpagosdolares                0.0052009630
# Visa_cconsumos                    0.0002940474
# ccomisiones_mantenimiento         0.0000000000
# ⋮                                 ⋮
# Visa_mpagosdolares                0.000000000
# Visa_msaldodolares                0.000000000
# ctarjeta_visa_descuentos          0.000000000
# ctarjeta_master_descuentos        0.000000000
# Visa_mconsumosdolares             0.000000000
# mcaja_ahorro                      0.084527457
# mpasivos_margen                   0.058899101
# mcuentas_saldo                    0.057910861
# Visa_mlimitecompra                0.030701321
# mtransferencias_recibidas         0.024870705
# Visa_msaldodolares                0.000000000
# ctarjeta_visa_descuentos          0.000000000
# cliente_antiguedad                0.000000000
# ctarjeta_master_descuentos        0.000000000
# Master_fechaalta                  0.000000000
# Visa_mconsumosdolares             0.583134447
# Visa_mpagosdolares                0.305489260
# Visa_mconsumospesos               0.038822593
# Visa_mconsumototal                0.038822593
# mtarjeta_visa_consumo             0.007000796
# Visa_msaldodolares                0.000000000
# Visa_mconsumosdolares             0.000000000
# ctarjeta_master_descuentos        0.000000000
# ctarjeta_visa_descuentos          0.000000000
# mtarjeta_master_descuentos        0.000000000
# Visa_mconsumosdolares             0.900223687
# Visa_mpagominimo                  0.131504591
# Visa_mpagosdolares                0.063927478
# Visa_mconsumospesos               0.063456558
# Visa_mconsumototal                0.063456558

# %% [markdown]
# ### Disgresión : aprendo a borrar la memoria

# %% [markdown]
# Listo los objetos que estan en la memoria de R en este momento

# %%
ls()
# Out:
# [1] "dataset"  "dataset2" "julio"    "modelo"

# %% [markdown]
# creo una variable a ver que sucede

# %%
a <- 1

# %% [markdown]
# me vuelvo a fijar que objtetos estan en la memoria, deberia aparecer la nueva variable **a**

# %%
ls()
# Out:
# [1] "a"        "dataset"  "dataset2" "julio"    "modelo"

# %% [markdown]
# tal cual esperaba, aparece el nuevo objeto, la variable  **a**

# %% [markdown]
# Me fijo cuanta memoria esta disponible

# %%
gc()
# Out:
#        used      (Mb)  gc trigger (Mb)   max used  (Mb)
# Ncells    796916  42.6   2661800   142.2   6498532  347.1
# Vcells 127241600 970.8 375998748  2868.7 375850195 2867.6

# %% [markdown]
# Borro **TODOS** los objetos que estan en la memoria de R

# %%
rm(list = ls())

# %% [markdown]
# Me vuelvo a fijar cuanta memoria hay disponible

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  795429 42.5   2661800   142.2   6498532  347.1
# Vcells 1700442 13.0 240639200  1836.0 375850195 2867.6

# %% [markdown]
# llama a **gc()** garbaje collection, que me va a liberar mas aún la memoria
# <br>
# https://cran.r-project.org/web/packages/profmem/vignettes/profmem.html

# %% [markdown]
# Ahora si, limpie bore todos los objetos de R y limpie la memoria
